# %% [markdown]
# <a href="https://colab.research.google.com/github/ShubhamDalvi1911/OOPs-With-PYTHON/blob/main/OOPs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
L = [1,2,3]
type(L)
# Out:
# list

# %%
L.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_8294/453846858.py in <cell line: 0>()
# ----> 1 L.upper()
#
# AttributeError: 'list' object has no attribute 'upper'

# %%
# Pascal Case - used to create class
# HelloWorld

# %%
class Atm:

  # Constructor( special function ) -> superpower -> constructor does not need to execute. it executes itself when we create object.
  def __init__(self):
    self.pin = ''
    self.balance = 0
    self.menu()

  def menu(self):
    user_input = input("""
    Hi how can i help you?
    1. Press 1 to create pin
    2. Press 2 to change pin
    3. Press 3 to check balance
    4. Press 4 to withdraw
    5. Anything else to exit
    """)

    if user_input == '1':
      #Create pin
      self.create_pin()

    elif user_input == '2':
      #Change pin
      self.change_pin()

    elif user_input == '3':
      #Check Balance
      self.check_balance()

    elif user_input == '4':
      #Withdraw
      pass

    else:
      exit()

  def create_pin(self):
    user_pin = input('Enter your pin : ')
    self.pin = user_pin

    user_balance = int(input("Enter Balance : "))
    self.balance = user_balance

    print('Pin  created successfully')
    self.menu()

  def change_pin(self):
    old_pin = input("Enter old pin : ")

    if old_pin == self.pin:
      # Let him change the pin
      new_pin = input("Enter new pin : ")
      self.pin = new_pin
      print("Pin Created Successfully")
      self.menu()

    else:
      print("Nahi karne de sakta re baba")
      self.menu()

  def check_balance(self):
    user_pin = input("Enter Your Pin : ")

    if user_pin == self.pin:
      print("Your Balance is : ", self.balance)
      self.menu()

    else:
      print("Nikal behen ke ...")
      self.menu()

# %%
obj = Atm()
# Out:
#     Hi how can i help you?
#     1. Press 1 to create pin
#     2. Press 2 to change pin
#     3. Press 3 to check balance
#     4. Press 4 to withdraw
#     5. Anything else to exit
#     1
# Enter your pin : 1911
# Enter Balance : 500000
# Pin  created successfully
#
#     Hi how can i help you?
#     1. Press 1 to create pin
#     2. Press 2 to change pin
#     3. Press 3 to check balance
#     4. Press 4 to withdraw
#     5. Anything else to exit
#     3
# Enter Your Pin : 1911
# Your Balance is :  500000
#
#     Hi how can i help you?
#     1. Press 1 to create pin
#     2. Press 2 to change pin
#     3. Press 3 to check balance
#     4. Press 4 to withdraw
#     5. Anything else to exit
#     5

# %%
print(type(obj))
# Out:
# <class '__main__.Atm'>
